# %% [markdown]
# <a href="https://colab.research.google.com/github/chaiminwoo0223/Deep-Learning/blob/main/14%20-%20Char_RNN_Naive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Download

# %%
# !rm -r data
import os 

try:
  os.mkdir("./data")
except:
  pass

# !wget https://raw.githubusercontent.com/dmlc/web-data/master/mxnet/tinyshakespeare/input.txt -P ./data
# Out:
# --2023-05-08 11:34:24--  https://raw.githubusercontent.com/dmlc/web-data/master/mxnet/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘./data/input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.05s
#
# 2023-05-08 11:34:24 (20.6 MB/s) - ‘./data/input.txt’ saved [1115394/1115394]

# %%
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.6)

# %% [markdown]
# # Import

# %%
import torch
import torch.nn as nn
import unidecode
import string
import random
import re
import time, math

# %% [markdown]
# # Hyperparameter

# %%
num_epochs = 2000
print_every = 100
plot_every = 10
chunk_len = 200
hidden_size = 100
batch_size = 1
num_layers = 1
embedding_size = 70
lr = 0.002

# %% [markdown]
# # Data
# ## 1.Prepare Characters

# %%
# import string에서 출력가능한 문자들을 전부 불러온다.
all_characters = string.printable
n_characters = len(all_characters)
print(all_characters)
print("num_chars =", n_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# num_chars = 100

# %% [markdown]
# ## 2.Get Text Data

# %%
# 다운받은 텍스트 파일을 읽어온다.
file = unidecode.unidecode(open('./data/input.txt').read())
file_len = len(file)
print("file_len =", file_len)
# Out:
# file_len = 1115394

# %% [markdown]
# # Functions For Text Processing
# ## 1.Random Chunk

# %%
# 텍스트 파일의 일부분을 랜덤하게 불러온다.
# (시작지점 < 텍스트 파일 전체길이 - 불러오는 텍스트의 길이)가 되도록 시작점과 끝점을 정한다.
def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# he haunts
# wakes, fairs and bear-baitings.
#
# AUTOLYCUS:
# Very true, sir; he, sir, he; that's the rogue that
# put me into this apparel.
#
# Clown:
# Not a more cowardly rogue in all Bohemia: if you had
# but looke

# %% [markdown]
# ## 2.Character To Tensor

# %%
# 문자열을 받았을 때, 이를 인덱스의 배열로 바꾼다.
def char_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return tensor
print(char_tensor('ABCdef'))
# Out:
# tensor([36, 37, 38, 13, 14, 15])

# %% [markdown]
# ## 3.Chunk Into Input & Label

# %%
# 랜덤한 텍스트 chunk를 불러와서, 이를 입력과 목표값으로 바꾼다.
# 예) pytorch -> 입력 = pytorc, 목표값 = ytorch
def random_training_set():
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# # RNN
#
# ## 1.Model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, output_size, num_layers = 1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.embedding_size = embedding_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.encoder = nn.Embedding(self.input_size, self.embedding_size)
        self.rnn = nn.RNN(self.embedding_size, self.hidden_size, self.num_layers)
        self.decoder = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, input, hidden):
        out = self.encoder(input.view(1,-1))
        out, hidden = self.rnn(out, hidden)
        out = self.decoder(out.view(batch_size,-1))
        return out, hidden
    
    def init_hidden(self):
        hidden = torch.zeros(self.num_layers, batch_size, self.hidden_size)
        return hidden

model = RNN(n_characters, embedding_size, hidden_size, n_characters, num_layers=2)

# %%
# 모델 테스트
inp = char_tensor("A")
print(inp)
hidden = model.init_hidden()
print(hidden.size())
out, hidden = model(inp, hidden)
print(out.size())
# Out:
# tensor([36])
# torch.Size([2, 1, 100])
# torch.Size([1, 100])

# %% [markdown]
# ## 2.Loss & Optimizer

# %%
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## 3.Test Function

# %%
# 임의의 문자(start_str)로 시작하는 길이 200짜리 모방 글을 생성한다.
# torch.multinomial() : 주어진 입력 텐서 input의 각 행마다, 다항분포에서 표본을 추출한다.
def test():
    start_str = "b"
    inp = char_tensor(start_str)
    hidden = model.init_hidden()
    x = inp
    print(start_str, end="")

    for i in range(200):
        output, hidden = model(x, hidden)
        output_dist = output.data.view(-1).div(0.8).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        predicted_char = all_characters[top_i]
        print(predicted_char, end="")
        x = char_tensor(predicted_char)

# %% [markdown]
# # Train

# %%
for i in range(num_epochs):
    inp, label = random_training_set() # 랜덤한 텍스트 덩어리를 샘플링하고, 이를 텐서로 변환한다.
    hidden = model.init_hidden()
    loss = torch.tensor([0]).type(torch.FloatTensor)
    optimizer.zero_grad()

    for j in range(chunk_len-1):
        x = inp[j]
        y_= label[j].unsqueeze(0).type(torch.LongTensor)
        y, hidden = model(x, hidden)
        loss += loss_func(y, y_)
    
    loss.backward()
    optimizer.step()

    if i % 10 == 0:
        print("\n", loss/chunk_len, "\n")
        test()
        print("\n", "="*100)
# Out:
#  tensor([4.5949], grad_fn=<DivBackward0>)
#
# b_xH	M?M!@jcUh"cpP@{>PDJfT%6BiP{z.}^VE}G)3ix`9vv,.<#1Q3r{Y*%T@%(}yxHD?t[-	{D'Kj.#tjU)T[L
# Bn'ss,*IV_{<>[<L(>Y$w^n97'Da'd"
# +`
#
#  ====================================================================================================
#
#  tensor([3.2770], grad_fn=<DivBackward0>)
#
# bC@` ie hrus ioe tsyotd1n ,GyneNhdi  s dnup tPkib-pnn teiLi,6  gle  ,aaoedl n eni*ith dtres{ai7uee Wi
#  aii`-.y.tu tn, os V tcsisnsyA aao' amtiitmorh:n fJiuitcuh,-sraowcU u iu nn rstohh o5ooL rl
# ue  o
#  ====================================================================================================
#
#  tensor([3.3283], grad_fn=<DivBackward0>)
#
# bn4
# tAP
# 9b3^["7OK,u Aatn
#  smyn, nou r arUl
# wemo
#  d l th irkher mhi oltm rtn drt
#
# I
# nengd n
# edPh ae
#
# wsesl oe f at
# s voed er f
# hd  d  n  rcrhho
# ,an:
# oea id eg.r I siem e dhIr
# onrnto  Dad!znn t
#  ====================================================================================================
#
#  tensor([3.0990], grad_fn=<DivBackward0>)
#
# bKra hrarCewd thenn  aise tu is te te sos lee  inecttiib; orwhom fby foan ateIrhErabtie oem ensefH oh srrsehVo Scumi ed dwe
# o paratn a ar Gotbot tihelf
# fhaa yea co me,; mef be
# door mo fher nn scegv Kl
#  ====================================================================================================
#
#  tensor([2.9280], grad_fn=<DivBackward0>)
#
# bui,h our Inb too,  ifelorhamotharenf moy weIsut
#
# e t|dp aen senr
# heeed waral yOr orhon thal heonoe toan weracl the fo none ton sralN do
# RecQans mae aen meAthe thand oo weEiselk so,os that rhoy fhdsorA
#  ====================================================================================================
#
#  tensor([2.7623], grad_fn=<DivBackward0>)
#
# b.
#
# Whom sod ke aos  hod Ian
#
#
# 4linTar
#
# Akts OoI ptais as le ittw sethear
# DLsink Sor shongd tont+in home fod theid womague nocese aus ehos,d ogise s oare
#
# rhabl aow mo, y, Iobe shabutu e rhand sole:
#
# O
#  ====================================================================================================
#
#  tensor([2.6736], grad_fn=<DivBackward0>)
#
# bme ouil ind biet tnusesethethesye
# Tntmere manhotw mol tin ait.B
#
# 5 hase Rhealf renrpaue there hes capeads
# IES:
# in henesSuugerprsey serandery nre Asthal att uciod mergaro rohe abugdvve'n mid
# mol ure yr
#  ====================================================================================================
#
#  tensor([2.6416], grad_fn=<DivBackward0>)
#
# bgvase tour ming anthere gapU mery bor.
# UJof rowir te tovr,
# Bcfsou ilty mort ees lice a' heCI
# , surd he, meinl des oce qrirt, mone ir mon:
# Sls arht, merissal vre Nore me meul ror min ar- lof thevol cin
#  ====================================================================================================
#
#  tensor([2.5139], grad_fn=<DivBackward0>)
#
# bk yand for are roum me tor ef an the thin
# Minl, orke, ho filt,
# Kinon themes oht thon theat ror y wir/Anrse theo
# qfalm thap thareirthoel, he hir hre ce an'er marpoC; al thmoasd bor ow my kite ans ry th
#  ====================================================================================================
#
#  tensor([2.6535], grad_fn=<DivBackward0>)
#
# bf ginl ye tes,
# Tnd I no dhe th teine be wol wor he ke so dthes Iine lo the hend nue the tard and ute Iwe bend tit then he momit be' rale dear me thang lor and aw mous mane ky co spe tid he ul oou cid,
#  ====================================================================================================
#
#  tensor([2.6430], grad_fn=<DivBackward0>)
#
# bss a woth hee is.
#
# WoV wascehe then, the with lichime doar hered basit thour he lt0uless lomis Vathy theas thas woaed welr lusssr orr anl tonrs lio's the by fades thas athet the
#
# Chasy im.
#
# MRLwSLO Yh
#  ====================================================================================================
#
#  tensor([2.5602], grad_fn=<DivBackward0>)
#
# b:
# Fot songhe time cover you wive ryou.
#
# AbEF:
# Watereveld hy foun.
#
# RARBUA::and meanr home olle oa soud this,
# Salroy be berin li.
#
# AREI::
# ARS
# TOY:
# Aorfey fute dire achas ind In bely feir toy the ooun;s
#  ====================================================================================================
#
#  tensor([2.3736], grad_fn=<DivBackward0>)
#
# bud blas yare meve And wangant thes ther bee yound: ye heas Hot abd meritet laem olan gueadt Leom.
# Nresol noves ogels that doale;
# .
#
# ACGE:
# Ay ma rive a hit in bth chencertans
#
# CUCR:
# PERRNWWEWENER:
# Mith
#  ====================================================================================================
#
#  tensor([2.3435], grad_fn=<DivBackward0>)
#
# bRpoin har
# lond
# Sor mover od cergast wheise herd mewent
# Ghess sro cor ye mither as the wot noce githas nfit, I dersee'.
#
# MERO
# TaRKETE::
# I sour irechrout sot ther un to srar wore,
# Thou shistertpentes; s
#  ====================================================================================================
#
#  tensor([2.3219], grad_fn=<DivBackward0>)
#
# beaces to.
#
# GEAUR
# NEFRDUSR)ANDN:
# MOW
# IO:
# Tcound nogiss catt alge ino thid rithe fhisa el,we
# Thul did thy to sithal ceae ting yit th moand andy faslob gent.
# :
# A mcorser
# Cowiile nis.
#
# EGTNOEOUA
# ASRWIAUM
#
#  ====================================================================================================
#
#  tensor([2.2855], grad_fn=<DivBackward0>)
#
# begen,
# Thou hin sher.
#
# The bank un;
# Ive le ind-ril!
# Hhe ding min and ms tik to the sinw,
# IN thes.
# CoR lrin moull thout why wind orn thne fy por,!
# Baow storland mes
# I when.
#
# OoR:
# Fhalt thim me thil d P
#  ====================================================================================================
#
#  tensor([2.2817], grad_fn=<DivBackward0>)
#
# bus, thil soun yo de the me at ave seid them ther the the the sile the le Gy tice you the sene sea day maag hen sor elicst,
# the thy hiso nons erat sredit bast in mull fe; in feun
# I themale heen me yid
#  ====================================================================================================
#
#  tensor([2.2000], grad_fn=<DivBackward0>)
#
# bKing ath mltid asave all wrrath rreis, more as buld the ce dor hath.
#
# [AOUA:
# 6o has, tor todt thou tt I llace ta darise to, are sing mes.;
# LI, RKININ:
# Mack nor yaant it sher, the is not ig Are toongs
#  ====================================================================================================
#
#  tensor([2.2278], grad_fn=<DivBackward0>)
#
# bies. in Gouth a namill ti to asie? oo asarethou abe bos on in ir
# I cof yor
# thee wist or ar aring, thes.
#
# erath paich ma it wasd fis toull non like are it.
#
# HEORTIE:
# Enoy ut oo on ir of us ro paslat mo
#  ====================================================================================================
#
#  tensor([2.2436], grad_fn=<DivBackward0>)
#
# be sorpeish;
# On, shave eo ther, giss my elle, I I Hfesale,
# I re ware wis thous sime beaes's wee boll ontest'des.
#
# LoRI
# WORTRS:
# GI lot the widl of ere hou sase thet nomen,rd be snevest,
# Gto pond, as sto
#  ====================================================================================================
#
#  tensor([2.2389], grad_fn=<DivBackward0>)
#
# bly yir efo sanide ond mel, haretars markingad inday mee thour tha meebfy tho batter'se eres olout with soradace lati this taik on and beave to the, of anste thit
# The art ant wouleler luond,
# What whhur
#  ====================================================================================================
#
#  tensor([2.2420], grad_fn=<DivBackward0>)
#
# bedlingid%.
# Yel memid, beand fures?
# And and ielst thit tome, hereast thed nodurl,
# Andtemy anked sobe a thith dothe steralkeng nhandteecosgidk beccoth in shave leing o thee theres, shoul beild wift cele
#  ====================================================================================================
#
#  tensor([2.1797], grad_fn=<DivBackward0>)
#
# busere wase sill.
#
# MSen:
# bous were, arer, I ty tAy she wike bith dome
# Thelr thin, have erow, wor, noof may
# Fomyienss go at anuan youd har be that he and kenthe das, and the, worogour page thou curth de
#  ====================================================================================================
#
#  tensor([2.2066], grad_fn=<DivBackward0>)
#
# bey.
# Hee, how mate. mind merss oith mens maand were in vell he hea shers you my and-star tous thomy cest ohd to had be tho math of turn to sterte vor shar, yoreste on the have houry sour I to ce poudf
#  ====================================================================================================
#
#  tensor([2.1358], grad_fn=<DivBackward0>)
#
# by'n dende so she ild an?
#
# TRSI wour this in wil, werpartoum. Winh hill shour sbe hou or hacour soo'm crlis the meleim, of ure thous gis hen an the serd at poas to purdelb pure dike you ford that an
# Wo
#  ====================================================================================================
#
#  tensor([2.1663], grad_fn=<DivBackward0>)
#
# bring and at thel fid the mand an hand to pe mane the feblousherouk: to delperw, her your inh senposens and the wouce teavel srar:
# Hnmest he to thour.
#
# PAESUTEF:
# Wiy sor: her, thor: mede.
#
# YOCNONARAE::
#  ====================================================================================================
#
#  tensor([2.2950], grad_fn=<DivBackward0>)
#
# blond, hing lown hacl? Vach wime that thowh hes: af id peat than molcring and tirg fur here be hele to bere'.
#
# TRECNOTET:
# Hell de.
# Wo and, marron wit fat cers.
#
# TRENEENEENA:
# :
# Che monl to the hannot he
#  ====================================================================================================
#
#  tensor([2.4334], grad_fn=<DivBackward0>)
#
# blean thout it of vake dooz to-hing so glou'd to dostand,
# Bood an oo sow fer and
# Brasridocloel your the mach this cupkird youck,
# Yous.
# Wish.
#
# BROK:
# Oe stant goome
# That hives I stall had alving
# Cowen pa
#  ====================================================================================================
#
#  tensor([2.1511], grad_fn=<DivBackward0>)
#
# burd ther?
#
# MOREST:
# Wath my I ster a wilbielird.
#
# HLRONCE:
# My bo bugtar; of mage merace sted thap wind as the hale and ofe, I with of net aglorrest lompares gorse mescend of sond catve,
# And
# Ard ske lie
#  ====================================================================================================
#
#  tensor([2.2147], grad_fn=<DivBackward0>)
#
# brother ave the dathineirter onptus thus af fon hime.
#
# DICHUMIN:
# Thand fum ane the meresfer in the the that berengor therer hongst or ong natht thige the los ant to the cither wis wour berile I his the
#  ====================================================================================================
#
#  tensor([2.0867], grad_fn=<DivBackward0>)
#
# ble mese she sond peock ctang cameiing mere ding loce longiliciin ar in hes I me her tonss Pisy long our chinh Gemen se thes nis bast if of prat you,
# Whesan ous and the ty sorat thiver there, wis af an
#  ====================================================================================================
#
#  tensor([2.1073], grad_fn=<DivBackward0>)
#
# by stome
# Oo beon, pond anfey like bead herou wome he weas to derall I lot, so ard hick our gulling pirapret soull cire by my hin deare, soust sourk.
# We wore:
# In alive fovinnts beand fores, thant un hea
#  ====================================================================================================
#
#  tensor([2.1824], grad_fn=<DivBackward0>)
#
# bstrens-yir Pfom noprom norst theatars cerance
# And drot winge his the oalst mos lont is dargorly her es andind fore for thou not hand what in hat butall hing,--
# And wond wo thee sarwserss
# 0eming hate a
#  ====================================================================================================
#
#  tensor([2.1459], grad_fn=<DivBackward0>)
#
# b, nemerst'd not of is is mare mike the lust you thol persone the ettes the ing the sfeat: and, Yut wour you be ther to ch the then:
# You ster sow pouighere soul to you KoosQ:
# Gispence, wis my a than mb
#  ====================================================================================================
#
#  tensor([2.1793], grad_fn=<DivBackward0>)
#
# be an gerenttor the sillf-ustyss will ute the o this of bow, ho rerlaons you moth hourgegarage to dout xor corch mane puname hidy
# Wopall me the a be our the loft thou, thon than to a'd wist as with to
#  ====================================================================================================
#
#  tensor([1.8837], grad_fn=<DivBackward0>)
#
# buplor.
#
# KFiRTlus brochpour dovarvech to, by bom gleof bais'd
#
# EO:
# I dith the moke hit fromed now and pobudfit love would math to be ing, thas at ah to nome the lad to eharsoue
# This rent-un
# Tha thou wh
#  ====================================================================================================
#
#  tensor([2.3415], grad_fn=<DivBackward0>)
#
# best thee,
# I vire
# Whither, and my.
#
# PUS6OWION PI:
# OLTAH:
# Lore crapith those the in so betione, pur, dut dapend than the elles it me ard that unpte. Tare menst on me thes, ele, gar coplove!
# These madear
#  ====================================================================================================
#
#  tensor([2.0355], grad_fn=<DivBackward0>)
#
# bears seart me thous hit you hath theiging with this and gath heangess ceind youk Whlis you and may be hit chit ut uearse hasto weve iy thees, of wid wist ca cend the; hom as fut non luve hell of done
#  ====================================================================================================
#
#  tensor([2.2181], grad_fn=<DivBackward0>)
#
# by seled be and spoce teather and be ceed cy you africe ceer, wo do the cow clows of tre as sealy.
#
# POLAOMHE:
# Wey eonter have a not ons the whey a sill suseing atere.
#
# TUSEN:
# Yo bathen sinth ingood sor
#  ====================================================================================================
#
#  tensor([1.9111], grad_fn=<DivBackward0>)
#
# brour is I bitied se I gortir besure the canntent tave cave and lostre:
# By to sill is orno of and.
#
# LUNORCMINLIUCEN:
# Here seabl your to willinge with her!
#
# MORONCORLTUCTAVINBEY:
# Mhall but shours cistar
#  ====================================================================================================
#
#  tensor([2.1027], grad_fn=<DivBackward0>)
#
# blds ming,
# The hich be kick pof as comes lood renthenced he the well his in?:
# I fale so thou this is for thes mall this the grof alled hinges',
# That thou mord ouf
# Ine it not ot not hil,
# And we stontem
#  ====================================================================================================
#
#  tensor([2.1082], grad_fn=<DivBackward0>)
#
# be; gling the silvon hath mame sour porest so shou the theathing beet for are werseny not ame that therest love ance mack notres ther it aplach the that oron be whore, dpaidterenoer
# Tove wike
# I choust
#  ====================================================================================================
#
#  tensor([2.2085], grad_fn=<DivBackward0>)
#
# by must a my you stall ol be it your she thes gartirse her, ay is so be in to shat a no! thup tham nogper qaelf in to do wargogst farrer ander,
# Antor may doves's searby Out me this and Hatiressme:
#
# IOR
#  ====================================================================================================
#
#  tensor([2.0147], grad_fn=<DivBackward0>)
#
# bed stremed me hinge?
#
# SEOLE:
# Nord ere the, there of by here the and there me me ils neartighert
# Furnentere wist contumere if turs his wich, thing ot his many droms see a the hond in weene, the wave yo
#  ====================================================================================================
#
#  tensor([1.9706], grad_fn=<DivBackward0>)
#
# bled'd to the king, vach, and eltels my lack, hot lough a tiss fors'nce to deols fear of I douns, fors, ands be arl the tello; tuester go cot captush cilfoen ast on a feorce-
# I the anstis sis, she moge
#  ====================================================================================================
#
#  tensor([2.2281], grad_fn=<DivBackward0>)
#
# becogerels my mole hadle wertain with for wisher have merparsech dy to thish ow farlint sanclome by wes, bo not and E'll?
#
# RORD IUS:
# Blwouter you fraxher bean bestich hidh jradem'sn moull my shorsort
# I
#  ====================================================================================================
#
#  tensor([2.0332], grad_fn=<DivBackward0>)
#
# bith yir, in the sfear.
#
# LERIUS:
# Nout my chose wence.
#
# LORZEN:
# Seep priep.
#
# LEONO:
# O sury!
#
# PURCOVILEN:
# Nut drangen,
# your Arof the who bever forl ut pring my the ringst end iest in lent.
#
# DINL:
# Youl we
#  ====================================================================================================
#
#  tensor([2.3707], grad_fn=<DivBackward0>)
#
# blon of thin noo ore the bey,
# And then duee; your and has tlou bencepan,
# Whou thas to not at lent, in in thy des hout thour he at to not with the enothan
# And You now have fuogfiped hay efore; rient hou
#  ====================================================================================================
#
#  tensor([1.9953], grad_fn=<DivBackward0>)
#
# buse the ard bemy
# Bes frouth daver
# Yerse the you buse the well tient dood esemter wis deon the mofe I that do fires of danes set a dadew--ave hame;
# And spae the deave are hourn now do thes alcosed nome
#  ====================================================================================================
#
#  tensor([2.1926], grad_fn=<DivBackward0>)
#
# burfest to diing staenciightremed inded, wheme gow your ourtichich infwa am yeld heald utserer, verpeatighasiin sive the sagier on to be.
# Lho gater stous.
# Yould;
# To manntrisces not,
# And not is thoust a
#  ====================================================================================================
#
#  tensor([2.1064], grad_fn=<DivBackward0>)
#
# browgreers ny thein, with a be.
# How there me lifes tomd wike it ture; to day the opt:
# And and doir the mouke hest tlerist the cowst;
# Grom, in mo to this him starce, no thee makes for and with dougating
#  ====================================================================================================
#
#  tensor([2.3771], grad_fn=<DivBackward0>)
#
# buchs bither.
# Cy lefur in were as sere then the ered suref;
# Ind thou
# do mes a lied dove ta thins ot made qrome and becison the my st your hem hot dath:
# The us and whee llal our of at with fich the dive
#  ====================================================================================================
#
#  tensor([1.9581], grad_fn=<DivBackward0>)
#
# ble,
# Ind tow sithen beawe mnen the fore lure her hand, a be with plaan, a lithoterraed beathe the sharst ur what vhothins thour hook,'d wime cay liteings ill theet, be thee aplice,
# Warn?
#
# EANE:
# Circe y
#  ====================================================================================================
#
#  tensor([2.1599], grad_fn=<DivBackward0>)
#
# becond,
# Mo see the wise an he will silles
# You not my hit?
#
# CRININANA
# Tay
# Whou keel a say show'
# Is to con alove fan or to the he our
# Wor the of fuhppeat theen: vered,
# Is
# Wame a whar thin I her if mood t
#  ====================================================================================================
#
#  tensor([1.6891], grad_fn=<DivBackward0>)
#
# blond this put thighs me butled your rrto cord.
#
# Fe I lith deoncht hemar, word my ke him use igar
# dreat it that ve the you sey
# Of hes binst acild.
#
# ARHARU works but that thates's,
# Witize If you not hei
#  ====================================================================================================
#
#  tensor([1.9117], grad_fn=<DivBackward0>)
#
# bightmed, and and and deartWise in thich wild mant frown:
# Ey your witen--Meretters at bo preathon, bum hath lead all than thy for the mishtaver theressefus the rother not all ast learsing as itrenterel
#  ====================================================================================================
#
#  tensor([2.2290], grad_fn=<DivBackward0>)
#
# bren son your bet not the vent and to sizer than of hounge: the dians
# Hetire,
# Asting you you lout fradous the rent!
# This thee as in that deshe as thears thy gongets atter-'s to nold brongen I caplooven
#  ====================================================================================================
#
#  tensor([2.3233], grad_fn=<DivBackward0>)
#
# bun with the come the porst.
#
# PUENCEN:
# Areand.
#
# DUTIO:
# So not the wirt so tofe get man the; and the son I whee shall of yoe spear for nod there thee there of he long: thid arardenin;
# And dother themane
#  ====================================================================================================
#
#  tensor([1.8508], grad_fn=<DivBackward0>)
#
# bartiot: a bingend of mone.
#
# SARKINVA:
# That to the this, bet in to he time not that dadden trentarest the you be fited and on Mise on shave dister's anagelf the thou wave speance, yow to wear hame anou
#  ====================================================================================================
#
#  tensor([1.8793], grad_fn=<DivBackward0>)
#
# by pake dome,
#
# HYOS:
# Hell hate weredrs sudded ancut friag cour is thou no as muble aur thell he sings, thou sherm?
# I plave.
#
# Su:
# A; I saye.
#
# SRIONO:
# What her as shy or,
# Home, dis there
# With hawnd in ha
#  ====================================================================================================
#
#  tensor([1.9801], grad_fn=<DivBackward0>)
#
# buse sint, some,
# Be mardelp of oe rothou htute thes, sour me much wourn.
# Hold poughthuthers mucastresores'd sie hath of soncemy heir thou beae, gove krre all enty being Lont you here of fort in that co
#  ====================================================================================================
#
#  tensor([2.1246], grad_fn=<DivBackward0>)
#
# buchart our wers ent my go durting a a oen enter thou hing:
# Bist sere. I the the that me beed wardy.
#
# BULKING:
# Wher dake be dourted me thall spars dis dap, ont.
#
# WARIO(E:
# Hath cordon this hing as the t
#  ====================================================================================================
#
#  tensor([2.0838], grad_fn=<DivBackward0>)
#
# bon soyon.
#
# PION:
# Wow his for nome
# Ned
# And fors, bnostreargan eis for it live is but the moweon'd hep his of brose uptoed abromes
# To the reath ogee fin in amise sedsers at. I kepiies kind Bown his farp
#  ====================================================================================================
#
#  tensor([1.9456], grad_fn=<DivBackward0>)
#
# bingy
# Ardrcours spon be thou and collle, shach be should bettily.
#
# GRORPENCES:
# Thought: no, your ald as thy his anwis to I his your sile came:
# In I kere healonewhou to defierser therey.
#
# IAUS:
# Bake as
#  ====================================================================================================
#
#  tensor([2.1270], grad_fn=<DivBackward0>)
#
# bough of thy heing to beppoth serou. Madll there-s;
# Gime in your the qaits, 'ponter in well the perting thou mave I lirn., porvast,
# Herourss nather to mant here and in the coman as will to herse the ca
#  ====================================================================================================
#
#  tensor([1.9884], grad_fn=<DivBackward0>)
#
# be the comtcher stous, seach and and a buth the buptent on apsounkss shall me them of men and for a let
# Of, ny pardon out Cabledlan;
# Ko her untude whenward in morto guer made hall is o pichperty sheld
#  ====================================================================================================
#
#  tensor([2.0075], grad_fn=<DivBackward0>)
#
# bone, ads, not hem,
# Nor to berough prod nas in ben minet of your come their fare fore gertings
# Of herfay we these thee ereed must bemane,
# The seat the hadd peadt in her
# That not I me son but hing:
# And
#  ====================================================================================================
#
#  tensor([2.0358], grad_fn=<DivBackward0>)
#
# ble yo, whis head parsey be cart it the ket, and thy be and Larress is the all it not will are must thy and gonest in the with this the themkind are you werr home their ip more whing Geall and, wand ho
#  ====================================================================================================
#
#  tensor([2.0015], grad_fn=<DivBackward0>)
#
# ble thall you sacin, thy and thou loked foir of coaboey.
#
# LUCRESA:
# To hing for cant sown outh our sewastiin if on a made: to a denoreress her we sors and more eyou my parsant
# him enoth a warred and goo
#  ====================================================================================================
#
#  tensor([2.0440], grad_fn=<DivBackward0>)
#
# being to but home for werrigh waster gate me dease our I le broo pone ho ponter haers withinhers for wing conking of hers; for hank:
# And reang mere my buter him the
# Oo to beref rise to there hat them l
#  ====================================================================================================
#
#  tensor([2.0719], grad_fn=<DivBackward0>)
#
# benest on as you, mint your suncenlies with entel the fathere shy harth sile's acies garte, pisean iy land it dringrec, late to lougharl, thea her's werunted spear's musieds with you is of my deart obe
#  ====================================================================================================
#
#  tensor([2.2099], grad_fn=<DivBackward0>)
#
# ble,
# Ho Sonoul the suret thank,
# AmA, awing I for for sirse sof, bet love beother I'll trivice hing bliont hade he the and thim shand difrear inture made are't gromver, of hem me souls hive tishing have
#  ====================================================================================================
#
#  tensor([2.2160], grad_fn=<DivBackward0>)
#
# but time, prolatitisniort bropred, beight at frightron to
# Am Mantle
# Pear she hence
# Wiim
# Anther.
#
# POMENGECEN YRARANS:
# My shar Thy lreal at crownour a sear's
# Ill and of to deld thear of the mat, mut not
#  ====================================================================================================
#
#  tensor([1.8884], grad_fn=<DivBackward0>)
#
# be be you have ve this potder's thou and yountel chiing your so poned then your on hell in your tell af preise fould the a hou it netid, the ag
# Have of lear do not think:
# The's you.
#
# QUDEINGELE:
# Go mus
#  ====================================================================================================
#
#  tensor([1.8291], grad_fn=<DivBackward0>)
#
# brower your nothied this forsean, that the pould I hadwer gould ward to this canion more the be will bewich shan it more the porced:
# I:
# Whour cond of aid it leef hisie;
# That shall restued the hard thea
#  ====================================================================================================
#
#  tensor([1.9355], grad_fn=<DivBackward0>)
#
# blace's do mone to couch me and honour twoll lip, thas wime; hear beeath, by of the faken lith your garcisecien as and to Er than both beade, sod, an ward the nopentist me I these asses; on frandoud se
#  ====================================================================================================
#
#  tensor([2.3872], grad_fn=<DivBackward0>)
#
# bues there gry have not be,
# Whis theel chousous, In son-unes, the wort beile a lach gar, I now mole as not fire Ibum tore.
# Yo sucmor:
# The wortll is nench collouplirgishall, them; is might capondee nath
#  ====================================================================================================
#
#  tensor([2.0920], grad_fn=<DivBackward0>)
#
# bimon thas done
# The gest.
#
# IUTANA:
# This what to mest, anst lanmice
# Brot the so's, sillan have ineroquishor;
# Whese a'ller listawn's blook were't beilld monanies is for now ghat sirstires.
#
# LURENRA:
# I hi
#  ====================================================================================================
#
#  tensor([2.0636], grad_fn=<DivBackward0>)
#
# brow's thy knove of our ut here late, it me fuw gather, and whip tipes that the dace hirs? Sine, and dear the exall the as unditnit.
# Tem nome the coue!
#
# LAUS:
# Af her searsind anger darve
# Will and our a
#  ====================================================================================================
#
#  tensor([1.8533], grad_fn=<DivBackward0>)
#
# bl and om he
# wolk whis troldsul to dweall debly rond hilges for dust comen the stars, Fot the so he waster and and thour your wis and the cand be saever goter hold buldy.
# -
# Aell no hour belousand be to
#  ====================================================================================================
#
#  tensor([2.0511], grad_fn=<DivBackward0>)
#
# bust.
#
# Tume enon head ould belighter think Sickhanger'd fuve't pean and exfer'd a trord.
#
# TERENRE:
# For And the wing knotherer:
# And but thy thak ard hampen thou menter me us we colfor he fatle.
#
# PRCARD:
#  ====================================================================================================
#
#  tensor([1.8572], grad_fn=<DivBackward0>)
#
# bucois that couse to lood lith lone our brick dors my lave spent thour no my dir.
#
# CERIO:
# I main thy eartered mare blout parsent his rrest beee glan nay: and Ad hosp at in is will me no lofble an;
# Why
#  ====================================================================================================
#
#  tensor([2.1733], grad_fn=<DivBackward0>)
#
# buspest.
#
# QARINIU
# That here wath for our ne and one not on
# Thy demt; not to the dears, det madistuon ppied,
# And
# And
# O make to a brand hers more and be in of defout hath and and lach of deconsion aparse
#  ====================================================================================================
#
#  tensor([1.7009], grad_fn=<DivBackward0>)
#
# be there not day,
# I not and corntnedy with the gshize nume
# ferse priith, sworse comy his the not, I sher to I lordy
# at with hif there the tor ind will not there now wan thing so be the surse detw the t
#  ====================================================================================================
#
#  tensor([2.0600], grad_fn=<DivBackward0>)
#
# bul' then vende for let lair, in they the sir dake and bearlod.
#
# HERCECLIO:
# That live spall in the not no erealt the prowist me his for I beet the bear bignce the nake the lied of listy, not no mue thi
#  ====================================================================================================
#
#  tensor([1.9326], grad_fn=<DivBackward0>)
#
# ble for done, busher we ditter
# Bocter: chis not sear to shore,
# Gout thour mear t'le and your,
# If fortiener my herice me,
# No frother,
# And laal your not not sharter,
# And the, stear the maut
# A mame ront
# S
#  ====================================================================================================
#
#  tensor([1.8425], grad_fn=<DivBackward0>)
#
# by furte, Of the me the a not not in my goy me the dace on cils! good how the dond;
# And thee conges me heremer whis the deads you my begitier my gach you soour me the buth me as have,
# Hars fiture in wi
#  ====================================================================================================
#
#  tensor([1.8402], grad_fn=<DivBackward0>)
#
# bou that to hame
# Bell!
#
# Pram a ctry you his I hamash this trear so ford incairter: agaw with lict us suct a hing brom my are the worsas ways-non lord do he are envy,
# And Bnothe e,
# Or hocear, and I prea
#  ====================================================================================================
#
#  tensor([2.0047], grad_fn=<DivBackward0>)
#
# blakes tirmour tand my fromist menaterty to dord this her, whis concatess come the coow you compentler, be,
# And thou there to a
# denting and the doet our themer tay, belive?
#
# DUy
# Whim will and bearicest
#  ====================================================================================================
#
#  tensor([2.1516], grad_fn=<DivBackward0>)
#
# bught atwens, shat for whit baht his dought, swoll than there ucetate me me thou hathin
# My't we garcast whis ware I lord to the mane sust his al sencentien the and thee lans the? may, shen, compian, an
#  ====================================================================================================
#
#  tensor([1.8566], grad_fn=<DivBackward0>)
#
# by men
# The lear!
#
# BRELFUAND IO:
# The kis compatiy, I have as liver in O Tone the shar dentlers,
# Therencor.
#
# FERTBUUTELLAND:
# My longun it has son heare nor, and me pootlianced you, sur-ay come to my stau
#  ====================================================================================================
#
#  tensor([1.9662], grad_fn=<DivBackward0>)
#
# broth, my my bould and doth my your me lit, of son'd thou heads early him your lied perefore rear inther, plied;
# O come our sumangering a cordsion my is somy of mistrong; gle late; im ills is comerator
#  ====================================================================================================
#
#  tensor([1.7039], grad_fn=<DivBackward0>)
#
# bust and cOusion for so my ress ware thou a prearo-werd.
#
# KFoSk:
# Hefen pleach his him hink's of he me us you the spons, and rangard, oun granss pray that O sive live a sermer dow my but me unsents in t
#  ====================================================================================================
#
#  tensor([1.9264], grad_fn=<DivBackward0>)
#
# burded so gill me that is his for one come: gancely and the in with the sureard
# Hither trake hen 'for randmon so dracked with rems sir! hourd minepery of a prears! come and partance, to so you concence
#  ====================================================================================================
#
#  tensor([1.9763], grad_fn=<DivBackward0>)
#
# bry the came the not wiqke have now is, have that must gloved Githhou have the comes, Ill to me your sir'd the must hour Andeat all danfor thing and you live throung the wold
# In these suntertuoling, an
#  ====================================================================================================
#
#  tensor([2.0031], grad_fn=<DivBackward0>)
#
# boust a morst,
# This hast
# May bown am he hither coad this sour such lill have this furgaas, efoum,
# He stevers on thes should I creachysely, your I nost on to the henest vine, and enoul mest oss, and his
#  ====================================================================================================
#
#  tensor([2.0964], grad_fn=<DivBackward0>)
#
# beth quard
# so there near be is lingst such dray as for his the dead; sow to kence
# Toben where for the nains now doth the have stall derce the hall the lent.
#
# PADIO:
# Barle with heer sprest the den there
#  ====================================================================================================
#
#  tensor([1.8992], grad_fn=<DivBackward0>)
#
# by cald of he forfaed,
# Herell our of toome,
# And ling and here of the given that the sle theeals at bain elo there fatres ol ix stain tone beich signter be dither's wheeed in yow seed for the at here al
#  ====================================================================================================
#
#  tensor([1.7018], grad_fn=<DivBackward0>)
#
# but me of fister'n to this come, a's my rost on all whur your do bity a have my have a ch, agver in me and to chall nerr have a becherch, and, Take this farrow shall to bear he mumy, in the cao, all to
#  ====================================================================================================
#
#  tensor([1.8863], grad_fn=<DivBackward0>)
#
# blaas thee must kno row ard do whuchard's but of here shy whost,
# For fachardy, all.
#
# KING EDUCHEm:
# For beceingry sharly God deasterefore thy grace, were plaine deice,
# If lead's lone; bide,
# Lort:
# And la
#  ====================================================================================================
#
#  tensor([1.9969], grad_fn=<DivBackward0>)
#
# bous he fathing me it of you well'd is spreaver for pother the mart to merve! and say with mant my Ould from the bands so yay whicht. CeWill as wam heart and to shill to your wis kill wall seall the sh
#  ====================================================================================================
#
#  tensor([2.6511], grad_fn=<DivBackward0>)
#
# be the be the canted your hour with you do our agarey. Dor not shough be theardany.
#
# BLARIO:
# His is bead to now, hip wethsarced.
#
# JRLARD ILA, be wing lord be warls, in cabe.
#
# QURIOEO:
# Folds of hus merh
#  ====================================================================================================
#
#  tensor([2.0665], grad_fn=<DivBackward0>)
#
# by the be, in any yough and the dancoman
# Fould light shall is wold tare this the are conbonus.
#
# Fwould that the sardea go may the to the sinsthangelols, mards
# Gone,
# Whing worther that will of preed the
#  ====================================================================================================
#
#  tensor([2.2394], grad_fn=<DivBackward0>)
#
# beted of hive he preengst lark fray forsurroter your not heed dookn he do beath with not our wence to do mishange purns here you mould thair:
# You brow chentrang:
# And and beed rewill be vell we dangiced
#  ====================================================================================================
#
#  tensor([1.7512], grad_fn=<DivBackward0>)
#
# becongs back knoch at of this not as hiir vid my, arter abeen.
# Geely.
#
# KONK:
# His to bar some aponming gesed's lord your prarey former:
# For that we me to mare bet your to plench to pround and call weir
#  ====================================================================================================
#
#  tensor([1.7112], grad_fn=<DivBackward0>)
#
# but and this revishildedy mire the ponto rentes not the mighter our sught, do as thention to the master thou gatther him: goe of the in their thou sold
# The come, not at me come.
#
# BEONIXANIUS:
# The brith
#  ====================================================================================================
#
#  tensor([1.6931], grad_fn=<DivBackward0>)
#
# bong unporungerw of the as his he to the you me, I light; I lits of to seawer the sould tusingry fantore in biightined
# The do cumen the suntedore of me beare and of cronter?
# The fanty a haster my sirs
#  ====================================================================================================
#
#  tensor([1.8940], grad_fn=<DivBackward0>)
#
# breas samtlean'd the red boult:
# The grant my brown ran whis mand have with desher?
#
# PAUSt
# The place can my peed if much umess
# und 'ver frant atwers,
# And light whres stremand the remen in him the caming
#  ====================================================================================================
#
#  tensor([1.9056], grad_fn=<DivBackward0>)
#
# buths my lord,
# Then the docess or devith forted the dest them,
# Cowragainted sur serveat;
# And trust and trander yire comterted piment with to mered timed tow the that a setries resent and there what be
#  ====================================================================================================
#
#  tensor([1.9639], grad_fn=<DivBackward0>)
#
# bet you have regious that well to a chore dey, that and
# Hake bucrion hought,
# My com his peice his grawe's mace'd now you sent sich me a say sumples
# Angry thy bouttrixhing thou thou to more mine of mine
#  ====================================================================================================
#
#  tensor([1.7236], grad_fn=<DivBackward0>)
#
# bess corall penseld.
#
# PRIOV:
# Trade late?
#
# RORIETHUS:
# How and father
# And hand by his beade hif kend's caud's allfolt. That at some, and you.
#
# GRUCENO:
# Thou worsile wail.
#
# LUCENTULU?:
# Shall bast have flo
#  ====================================================================================================
#
#  tensor([1.8649], grad_fn=<DivBackward0>)
#
# but fort'st may pall manify be then will be tind more that, go all tome goes but we and but
# And grown.
#
# DUCOXENSE:
# In penainus' to to wears wenk it tust were apt abloty,
# Whe shis the winds hit in him t
#  ====================================================================================================
#
#  tensor([1.9064], grad_fn=<DivBackward0>)
#
# benturred your have not were'ss bandeed: with man your an bescout reWort fuet shorour corcut' he may thysenting it to alch it that fation fory cearing
# Put reare not some to as gord go there
# caughtirike
#  ====================================================================================================
#
#  tensor([1.7474], grad_fn=<DivBackward0>)
#
# brefore be promy isseed sesend curk nould, to he laegerfforick renreser he should the hath sell; for colmon to my liamf heall to hit full not your furned; I at to bload airst.
#
# EUCE:
# Dood shily gripe.
#
#  ====================================================================================================
#
#  tensor([1.7805], grad_fn=<DivBackward0>)
#
# brong the pary: the, in oll pra? and faress
# I not now langer head me?
#
# Plabled will as I a nen in they not fol thim sardent of coust they for a hate a me, semder
# Gon wese me me loves yet'n prate:
# But y
#  ====================================================================================================
#
#  tensor([1.9181], grad_fn=<DivBackward0>)
#
# briked housee of thou his like to be not.
#
# PETR IO:
# I pould cowerd think is have of there went of our hadd, gooder,
# That now 'drand her
# candrountion thou pantutier ourse as no him from hath?
#
# Nurth as
#  ====================================================================================================
#
#  tensor([1.9818], grad_fn=<DivBackward0>)
#
# bress.
#
# LEON YLONFOLELO:
# Lest in in this not thing'd to wook herpers,
# Henemen to than?
#
# LOME:
# MuRe word's thee, so woold, the with making's dople dive boon trom woil bust here I brong or farwerd that t
#  ====================================================================================================
#
#  tensor([1.8416], grad_fn=<DivBackward0>)
#
# bford, I word, to listarder tackens, I come, of his had
# A forst!
#
# The wistent;
# come in so, able,
# And neer of he prietter, thing.
#
# ELIZAN:
# Bud of my preefenings thour fearfen troungrest lieds we have he
#  ====================================================================================================
#
#  tensor([1.9357], grad_fn=<DivBackward0>)
#
# but not rut their my the breople timetnous that thee, and ind had that show the come of that you. I are my best the wing you hand his not t
# he cancire
# And sord rake this, nom now in tume lies to bry th
#  ====================================================================================================
#
#  tensor([1.9057], grad_fn=<DivBackward0>)
#
# blous yir, on speathfress comserve be't apparlited ont sofls lienderch doight; in uppall to opurcfiand.
#
# RPmIk:
# I will vict's to see dones the comes natuon
# I seavelay mise
# What his fordarge a that ange
#  ====================================================================================================
#
#  tensor([1.8649], grad_fn=<DivBackward0>)
#
# by Tider he difer's stamp! with the, me some
# Barright my glaw to jrow in words him him hor to you dome in with who to be at him do the cay you the nofher
# A should true Murst an whore wiss can the garsa
#  ====================================================================================================
#
#  tensor([1.9270], grad_fn=<DivBackward0>)
#
# boud sire his be; be you, shoughtent hour endy dead me; be tocest charand you wing spear
# Agreate, I chiisege
# Her is cromish's nead deabice thou Marth,
# unted relancus me wend the which uncome feass thy
#  ====================================================================================================
#
#  tensor([1.9565], grad_fn=<DivBackward0>)
#
# bry wood:
# Well that I pest as tay.
#
# CMANGAk:
# The to to foelt enome Marives me the dich with you my my the sich heme?
#
# PRICMINIUS:
# This ovelel,
# Thereling oniit the, Coor that we the soters ollever here
#  ====================================================================================================
#
#  tensor([2.1184], grad_fn=<DivBackward0>)
#
# blowing.
#
# ANTENE:
# Is lake
# To to muse
# theremond you lio's llock as to pare the wele of but bath, in a craoly the death, prief come dase a spire you to dose wo with a gay to more a vidaint.
#
# ETMANTO:
# Lat
#  ====================================================================================================
#
#  tensor([1.9787], grad_fn=<DivBackward0>)
#
# bears in with indire, the sancusparlows or she not, dicriint an fized the daded
# In to son, awn, mutistizent divine in now your bedved
# Have pought comy bease.
#
# PriRpon eoker,
# And me trake biitiect will
#  ====================================================================================================
#
#  tensor([1.8853], grad_fn=<DivBackward0>)
#
# ble she is so mant time to my somes, pray thein pray more a saler come the lied? You biseld;
# And eresceds depond my fet heaver now men lang must the to made I me hominend the gouse; voves
# Be it our to
#  ====================================================================================================
#
#  tensor([1.8146], grad_fn=<DivBackward0>)
#
# bly
# And to thou man plarel his negite, wils his nomand the kerder of tentely hercumer vempoors to lats as as bost's, we to a for thou home;
# Where of on here he sword in thee, be unter: and to lown the
#  ====================================================================================================
#
#  tensor([2.1384], grad_fn=<DivBackward0>)
#
# bremant, arry, by amt
# Do and my lost treman may you is karrake use
# In the all and I homen light Or the sear kings you and his primade how this wruse than he well vese and tell,
# Of had hin.
#
# LUCASLA:
# So
#  ====================================================================================================
#
#  tensor([1.7420], grad_fn=<DivBackward0>)
#
# but the fordous sure his beatt eath serve the woar an that bed the his to my rettorded seams ance us thy she the deept, you.
#
# WERIUS:
# I that beet my arbse then of head in the ampless in fet a dost that
#  ====================================================================================================
#
#  tensor([1.9636], grad_fn=<DivBackward0>)
#
# bul thou to there the mkere the cied: I winnong the diece;
# Aw, do paincoum.
#
# LORONGAR':
# I king he may the elodnour mave me and, will sick of the sirse, son,
# And the not the home, no nroun!
#
# ISIO:
# Beitt
#  ====================================================================================================
#
#  tensor([1.7960], grad_fn=<DivBackward0>)
#
# ble of as poly happerwing the worle:
# Of my dars alate thus stels.
#
# CATIO:
# Thy doth son holle
# Dong me, recome Rolfent.
# What in thy goect?
# What eggald mother to astry well the ollard,
# You word,
# In will b
#  ====================================================================================================
#
#  tensor([1.7820], grad_fn=<DivBackward0>)
#
# by and bloceed to not sune father a quodling braince.
#
# DUCHIO:
# Hemsed ary forstent a king!
# By and
# Content heith theing thenersalike it I mone he this lies:
# Nou not boustust:
# Hrous sagned hath:
# As that
#  ====================================================================================================
#
#  tensor([1.8751], grad_fn=<DivBackward0>)
#
# brea. Frong with well stamires as in enpark again:
# Not in thou harrs, whee or worl:
# I and lawn am eneet a then the wife sons
# And I will in hemselffors her speak, ip me the jound in that tumam:
# They of
#  ====================================================================================================
#
#  tensor([1.7349], grad_fn=<DivBackward0>)
#
# but fine', will to Pryels for what the helm?, and with your simory woost and you that for stolset
# To and we foress me cose be weld exett, unrill shal is ard come ip by wilt naglornce to the marther wor
#  ====================================================================================================
#
#  tensor([1.9595], grad_fn=<DivBackward0>)
#
# bonge, as fighter think out
# The stanncencain, his homen ame:
# I their Kidon the day am wirtand rights woth,
# And here bormen:
# And the came all pomplay, he son
# so-manine,
# And all to the could, 'tim gords
#  ====================================================================================================
#
#  tensor([1.6692], grad_fn=<DivBackward0>)
#
# betion,
# That has our comes a staid mastorning of came a vancer: you charsednden shall;
# Will a nevaring, and you hast a wear sirith you had honour?
#
# AENTAL:
# And panless thy one our have my cumeds if is
#  ====================================================================================================
#
#  tensor([1.7919], grad_fn=<DivBackward0>)
#
# bly caurte,
# And.
#
# COFO:
# That with your Noldre, I with hem. Host the she lost gate and he for croome
# In the Ay, tell sould is some you your not there off me the don serven, I lord.
#
# Shall stay are seam
#  ====================================================================================================
#
#  tensor([1.7401], grad_fn=<DivBackward0>)
#
# be trust
# bus shis thee mauke it spespother
# Wears a part
# Wey shall death-proct art shall she prost his mave of they wanderancesty.
#
# LLORD:
# Sest them
# Hist:
# As from a.
#
# SEDLUNCESTER:
# So thy sent?
#
# Kards t
# ...
# But do coqfict, and the Amines ENunlaning no lome gatt you hand
# shall beor the we Trank'd hath cill?
# Prover boyerpers,
# Where deake,
# And in is cake and ear to be and da
#  ====================================================================================================
#
#  tensor([1.7940], grad_fn=<DivBackward0>)
#
# braiten my hand you have the fect tell thy the dounds
# The the shall thou kneeds alt thuck what seet by the so vepty; my, you:
# What say, be me as and deadme, what may the peatcendy?
#
# DUKE VINCENTIO:
# Hei
#  ====================================================================================================
#
#  tensor([1.7247], grad_fn=<DivBackward0>)
#
# bless merely, or the deather conders this deast paint:
# Bespert of have to live and sisired helders ord masttry the give mastering of this warst:
# Thanks
# Tlate untelytence.
#
# SMINBED:
# I prend.
#
# POLIO:
# Som
#  ====================================================================================================
#
#  tensor([1.6540], grad_fn=<DivBackward0>)
#
# beath fore fears to prangend
# If tife my marry deep be,
# Than the munses a caret I parself, my cage heart, and to in no merion. Gow, sure your not am
# sheed apto marter forse and what the it the galyscent
#  ====================================================================================================
#
#  tensor([1.9149], grad_fn=<DivBackward0>)
#
# blaents thy shall are the sir, the revils the dost or Sirts pray eargent approon,
# That in to a ire the by under oury, the eport thou hark mados make treavedest if his bests at a marxardaad the tonce an
#  ====================================================================================================
#
#  tensor([1.6803], grad_fn=<DivBackward0>)
#
# ble, ay,
# The food worstands, and bring should up fetily bries then my yourson and should she toose you bear, dorthy a( I
# to dower, as the bank'dow of in sould a may I have dear maye then, fail, in the
#  ====================================================================================================
#
#  tensor([2.0800], grad_fn=<DivBackward0>)
#
# blower's a cemsay that ar will loves we flake.
#
# MERNE OM:
# What he powe?
#
# LEONTES:
# The should like,
# Wherelant see stand a brions till my blawe, shall, and shall they speath with's with with a at when mo
#  ====================================================================================================
#
#  tensor([1.7789], grad_fn=<DivBackward0>)
#
# blow not To lewer:
# Is the stand
# As the dadon not driver'd the have the look of here the mall the look.
#
# KAND IC:
# I have here then the punce, the sacter you, of is the late haster the hate the scontlot
#  ====================================================================================================
#
#  tensor([1.9037], grad_fn=<DivBackward0>)
#
# bries. There is is compon the hade.
#
# The him have
# O, ke wid,
# And hast you have hing of it houch lood he like in is suce,
# And for eart to him son leave mostoul horshers; So mople thas inturso to canford
#  ====================================================================================================
#
#  tensor([1.9027], grad_fn=<DivBackward0>)
#
# bay this for him:
# Ty may misburt;
# And me you hear with bouth the to I ammores.
#
# KALT: Rome, and gloot you seasine.
#
# POLANGTES:
# Angher,
# I'll him, shountrentles that I'll be he play thing he deads, and d
#  ====================================================================================================
#
#  tensor([1.9046], grad_fn=<DivBackward0>)
#
# be in the that again;
# Bee fronly a pertous.
#
# DUCHEND:
# To the most my barried:
# And serve oal, them out facents: and I have rester, would than eress well rear.
#
# NOl sid lie, the rofter,
# Whou the franut h
#  ====================================================================================================
#
#  tensor([1.7447], grad_fn=<DivBackward0>)
#
# ble plays, be my quly the marring the manting them; scould live rualled not his, and strove they the goastiant of full we nown that my wifen you 'he guents the the play my litters of my lost scome to m
#  ====================================================================================================
#
#  tensor([1.8942], grad_fn=<DivBackward0>)
#
# brever all to the was I canest your liust,
# That hear bloss arthing our minety your fraces;
# Arather are you hath the seppers, plack ot my fruncet, bewert, sale, the gentlend then hour not.
#
# CURIMCUS:
# Th
#  ====================================================================================================
#
#  tensor([1.7395], grad_fn=<DivBackward0>)
#
# blest: velvon take my grave on your speever of of this with for thit for for me enders; your rejourt cwars with of the pether:
# But lest:
# That of from me of of the love my eviles fries for men in the fa
#  ====================================================================================================
#
#  tensor([1.6100], grad_fn=<DivBackward0>)
#
# bloust then it be greast is mowe me?
# What my mead seevour
# Whoo the lost:
# Whe look, we dettle
# bearn the single he him to help Condes,
# Then baniend will my litter hand;
# He mand uncomine and co heard,
# Wha
#  ====================================================================================================
#
#  tensor([1.5450], grad_fn=<DivBackward0>)
#
# burioner Conceef.
# Wheir now mught foults court do blo;
# That hath of the fortle, and kneeen in thought our stanter, your such the masted with combutess uptert unking stire on carsend versurded lade prow
#  ====================================================================================================
#
#  tensor([1.7487], grad_fn=<DivBackward0>)
#
# bone of his impop take have make the
# goneed thag the pamice and look yes ame and the doen glook you we longe, no must that in Gongent we the ouse atting? you wrong helse this may put me thou comsers lo
#  ====================================================================================================
#
#  tensor([1.8191], grad_fn=<DivBackward0>)
#
# byienst the partion dower that are to the wild haluster, one ustase the.
#
# FIANTE:
# Thold, and come warrs
# The may, for hive things
# And the powersitite,
# That them us cless on the encters, I lan's it with
#  ====================================================================================================
#
#  tensor([1.6251], grad_fn=<DivBackward0>)
#
# busorys me me be
# Her wan eno cremand that I and say will good
# for Off, not one, I wor way, and said suselas of it besiin!
#
# QUEEN ELIZABELLA:
# What shallower thou fain's drate of the condient, gither sha
#  ====================================================================================================
#
#  tensor([1.8946], grad_fn=<DivBackward0>)
#
# bee fatian of it office.
#
# DUKE RIONE:
# Where exitle so micious if that's
# And your worthe say, and greats, what my if the know of Youm your all thou sused wame tile call of. What now your grant:
# To antin
#  ====================================================================================================
#
#  tensor([1.9446], grad_fn=<DivBackward0>)
#
# ble, like for I know your sure this with the dark sire.
#
# QUEEN:
# T the would shreablard and the sweeo
# chough that life, lew be the swill the dread not you mare gookn haster, thou ware this do moray home
#  ====================================================================================================
#
#  tensor([1.8340], grad_fn=<DivBackward0>)
#
# bliccess, gree the more clight the prischales one your hast ingthe ponce be the all thear this as the dicess
# Messs!
#
# PRINCE:
# When our take our hear'd, to the prong trens, made, him this this the press
#  ====================================================================================================
#
#  tensor([1.7383], grad_fn=<DivBackward0>)
#
# bord the before deriad o't the fat, I rever of done, for makce thou mademy bud deave of that some beshone thy filpar's bother one or the mead!
#
# PORDENET:
# O cradity this hoth of of did she the more dead
#  ====================================================================================================
#
#  tensor([1.8528], grad_fn=<DivBackward0>)
#
# buty thy forst hen of think but thing no reet having at thou is sarus the wor yet none if me,
# Who my deave who me conded him the have not thy unonother spelf. Gost, and the wall day a comes;
# To of I na
#  ====================================================================================================
#
#  tensor([1.9794], grad_fn=<DivBackward0>)
#
# bud toint here not.
#
# PRONEY:
# I nuy-king he ment on me thee is for the Got and love him aning Yourt your wauld besters. This have that be not to where all I'll speat the death and in ell to let wither h
#  ====================================================================================================
#
#  tensor([1.5971], grad_fn=<DivBackward0>)
#
# bucks and werefore dast Jlord than than is to ark them I bownt a grees the the dudss make being? sous fay thy hadf not sell this are are dost, fair, what that me ungers, be wencast, be an of the deselv
#  ====================================================================================================
#
#  tensor([1.8881], grad_fn=<DivBackward0>)
#
# benty are to prick'd you feer, whowles of your fill gick thath;
# But lades,
# To thy rovess.
#
# MINCET:
# Why lime that of my gropund hid prowned for ean whongure
# The gonted in the world.
#
# MARPEY:
# If not if t
#  ====================================================================================================
#
#  tensor([1.7457], grad_fn=<DivBackward0>)
#
# becior your prowers age, I dries,
# We lay thing heet all the seep, are we bragesh for the Oreear
# Why will, me heariting, a dowe; tooge out ip sause all you faring, have not parcely
# I warreman hath of me
#  ====================================================================================================
#
#  tensor([1.5534], grad_fn=<DivBackward0>)
#
# ble offorn of him my know and your knein.
#
# LORDKANO:
# A parter'd now on hother,
# What what my were my weich in his wist it in with the call sir,
# The nother my like aptity bonnecunessing the with he press
#  ====================================================================================================
#
#  tensor([1.7452], grad_fn=<DivBackward0>)
#
# bied, what the earrance have provents the shours, chase we she deat, and it send, threes, and but, whit in the crombous, what warus, have thy as the combut hother, title thy world: by in entios, with o
#  ====================================================================================================
#
#  tensor([1.8378], grad_fn=<DivBackward0>)
#
# butien:
# My reseast the lord be
# blicty?
#
# PRORY:
# What, fares teranters.
#
# COMINIUS:
# Nor world wind wingio resme a vant so the tone to thou queen you it one it now make me my loves
# The before is a preatort
#  ====================================================================================================
#
#  tensor([1.8050], grad_fn=<DivBackward0>)
#
# by his were my marry father will me very cole the should thereman:
# All most, and sepurtle you? sore, he elen, them desed of lord is eather by combous your nooget.
#
# DENENE:
# When to the no cown so to he
#  ====================================================================================================
#
#  tensor([1.8834], grad_fn=<DivBackward0>)
#
# bilowing?
# Pring to seall
# En be the lord, in all thought more some farth,
# And the suntle sould of the sould I a bing.
#
# SLAY:
# I lad is haw you, and for billlenely my yolate?
#
# ROME:
# Leaple and forie you,
#  ====================================================================================================
#
#  tensor([1.4609], grad_fn=<DivBackward0>)
#
# ble piy, I with wrice,
# With the hant your.
#
# LERENEE:
# Father:
# The complempertidn's hones though.
# That be to meather suppand soful him his deand; good, of Offure ever of that ratish.
#
# PAUKE
# WENCE:
# To cay
#  ====================================================================================================
#
#  tensor([1.7529], grad_fn=<DivBackward0>)
#
# best all barrance to hand, my canstranger that the carmand, blofe, sirst the brom thou in diffues his cause.
# Ray should that To my lifed, this blown:
# Haye if the mustor, and to made to noir know the hi
#  ====================================================================================================
#
#  tensor([1.7255], grad_fn=<DivBackward0>)
#
# bundere,
# So who betiss the brofquot the sause.
#
# KING RINIUCE:
# Who to do vient:
# And so son my life, hold good this have yebron hould I fair,
# The her, you comes thou her:
# A put to him resbray.
#
# QUEEN ELI
#  ====================================================================================================
#
#  tensor([1.8825], grad_fn=<DivBackward0>)
#
# bloodmore, lord:
# Gook on deat,
# this notlout preven have if she fortent so know my lave the ears: the forted woust not lein the teir have her full what fears fall: popery
# This got of lose gone is forten
#  ====================================================================================================
#
#  tensor([1.6824], grad_fn=<DivBackward0>)
#
# byo's fird the det as Hast, anch
# his duse, in their, Hercemone mine ancoumany hold.
#
# SoCportter, the father this would in eelf some pland, more did attlempny and preated ont the in, me more at slied Ha
#  ====================================================================================================
#
#  tensor([1.5857], grad_fn=<DivBackward0>)
#
# buse Hor wad to made ack from to pring parts like the she rote a pourilim.
#
# CARICLUMENE:
# What the lay,
# The strious if love at the sain with in selving sare, to merch of first a will will to a the bry h
#  ====================================================================================================
#
#  tensor([1.9374], grad_fn=<DivBackward0>)
#
# by mother, I am a way the wild hath or there's come, be ance sind of the kind:
# But the hand, and ention my medilenion day let
# Which we loult the seaments the hing me all your Rall the brople tild hould
#  ====================================================================================================
#
#  tensor([1.7930], grad_fn=<DivBackward0>)
#
# bing feend on well with to men fill then than the tet joy some is rew'smenge, I will go mustarding this slimbs
# Come thy best.
#
# FORCHAS:
# Than to so have the your comporden for ellower your kir, and all
#  ====================================================================================================
#
#  tensor([2.0230], grad_fn=<DivBackward0>)
#
# blower the bay
# Aface,
# Hath diad
# Miild to thou messnomen,
# Ambor himses. cough one
# bevother, where in that to morier:
# Os of excondery's interses of thou with is some to better kive
# Murse.
#
# LARDIUS:
# Sheir
#  ====================================================================================================
#
#  tensor([1.8874], grad_fn=<DivBackward0>)
#
# bettle your was,
# Eed of his menised for witt of me?
# Grand the wordess apor your place,
# I pretent the vonase, het that this,
# Mone preath actry the couly partion hand, it. Your of his exthe fill know'd m
#  ====================================================================================================
#
#  tensor([1.7436], grad_fn=<DivBackward0>)
#
# breepst,
# For ay death shounts, wither the gentlust of the gise in of peace, give the would the prist him hath what of child the with it wate send she fatrues; and dead's, in they thears,
# An one tell Mu
#  ====================================================================================================
#
#  tensor([1.7866], grad_fn=<DivBackward0>)
#
# breade: to leads, were the suin.
#
# HONTALY:
# The nother; what be of have to my is were me tran in coursed our stalarscemend strear;
# Why sofl a counder make and the cleedied:
# I bringed the cearth,
# And mog
#  ====================================================================================================
#
#  tensor([1.6736], grad_fn=<DivBackward0>)
#
# bordiins his try should thou be a crost shy ere these is in are of his holds she lie of couks; love, brow the boas so lieddy, the for thou have I ko hams and which
# Masturers;
# And art the was and I nowa
#  ====================================================================================================
